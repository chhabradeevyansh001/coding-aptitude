# %% [markdown]
# <a href="https://colab.research.google.com/github/chhabradeevyansh001/coding-aptitude/blob/main/coding_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Coding Lab")
# Out:
# Coding Lab
